# %%
import sys
import pandas
import numpy 
import os.path
sys.path.append("..")    

# New data frame
data = pandas.read_csv('data/sf/sf-passenger-count.csv', header=0)
data.tail()
# Out:
#         TRIP_ID  ROUTE  DIR  STOP_ID  STOP_SEQ  TIMESTOP  ON  OFF  LOAD     DATE  \
# 513780     2306     17    1     7205        27  23:22:04   0    0     4  10/7/12
# 513781     2306     17    1     6899        28  23:22:34   0    0     4  10/7/12
# 513782     2306     17    1     6896        29  23:23:21   0    0     4  10/7/12
# 513783     2306     17    1     6905        30  23:24:30   0    0     4  10/7/12
# 513784     2306     17    1     6739        31  23:24:51   0    2     2  10/7/12
#
#         LATITUDE  LONGITUDE
# 513780  37.73461  122.47147
# 513781  37.73648  122.47062
# 513782  37.73815  122.46882
# 513783  37.73965  122.46703
# 513784  37.74071  122.46584

# %%
passengers_on = data.drop(['DIR', 'STOP_ID', 'STOP_SEQ', 'TIMESTOP', 'OFF', 'DATE', 'LATITUDE', 'LONGITUDE'], axis=1)

passengers_on = passengers_on[data.DATE == "10/1/12"]

totals = passengers_on.groupby('ROUTE').ON.sum();
totals.head(10)
# Out:
# ROUTE
# 1         731
# 2        1922
# 3           1
# 5        4160
# 6        3028
# 9        4260
# 10       1393
# 12        933
# 14       6077
# 18       1153
# Name: ON, dtype: float64
